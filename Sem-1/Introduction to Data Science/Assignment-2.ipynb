# %%
#Importing some Libararies for Solving the Question in the Assignment
import pandas as pd 
import numpy as np 
from scipy import stats

# %%
#Readign the CSV File 
df = pd.read_csv('/Users/someshghaturle/Github/Masters-in-Data-Science/Sem-1/Introduction to Data Science/problem-2.2.csv')

# %%
#Drop Unnecessory columns Or
#Select only the necessary columns from the dataset.
df = df.drop(df.columns[-1],axis=1)

# %%
#Checking for the Data 
df
# Out:
#      ID   Purpose Length Lanes Clear   T OR D Material    Span Rel-L
# 0    E1   HIGHWAY      ?     2     N  THROUGH     WOOD   SHORT     S
# 1    E2   HIGHWAY   1037     2     N  THROUGH     WOOD   SHORT     S
# 2    E3  AQUEDUCT      ?     1     N  THROUGH     WOOD       ?     S
# 3    E5   HIGHWAY   1000     2     N  THROUGH     WOOD   SHORT     S
# 4    E6   HIGHWAY      ?     2     N  THROUGH     WOOD       ?     S
# 5    E7   HIGHWAY    990     2     N  THROUGH     WOOD  MEDIUM     S
# 6    E8  AQUEDUCT   1000     1     N  THROUGH     IRON   SHORT     S
# 7    E9   HIGHWAY   1500     2     N  THROUGH     IRON   SHORT     S
# 8   E10  AQUEDUCT      ?     1     N     DECK     WOOD       ?     S
# 9   E11   HIGHWAY   1000     2     N  THROUGH     WOOD  MEDIUM     S
# 10  E12        RR      ?     2     N     DECK     WOOD       ?     S
# 11  E14   HIGHWAY   1200     2     N  THROUGH     WOOD  MEDIUM     S
# 12  E13   HIGHWAY      ?     2     N  THROUGH     WOOD       ?     S
# 13  E15        RR      ?     2     N  THROUGH     WOOD       ?     S
# 14  E16   HIGHWAY   1030     2     N  THROUGH     IRON  MEDIUM   S-F
# 15  E17        RR   1000     2     N  THROUGH     IRON  MEDIUM     ?
# 16  E18        RR   1200     2     N  THROUGH     IRON   SHORT     S
# 17  E19   HIGHWAY   1000     2     N  THROUGH     WOOD  MEDIUM     S
# 18  E20   HIGHWAY   1000     2     N  THROUGH     WOOD  MEDIUM     S
# 19  E21        RR      ?     2     ?  THROUGH     IRON       ?     ?
# 20  E23   HIGHWAY   1245     ?     ?  THROUGH    STEEL    LONG     F
# 21  E22   HIGHWAY   1200     4     G  THROUGH     WOOD   SHORT     S
# 22  E24        RR      ?     2     G        ?    STEEL       ?     ?
# 23  E25        RR      ?     2     G        ?    STEEL       ?     ?
# 24  E27        RR      ?     2     G  THROUGH    STEEL       ?     F
# 25  E26        RR   1150     2     G  THROUGH    STEEL  MEDIUM     S
# 26  E30        RR      ?     2     G  THROUGH    STEEL  MEDIUM     F
# 27  E29   HIGHWAY   1080     2     G  THROUGH    STEEL  MEDIUM     ?
# 28  E28   HIGHWAY   1000     2     G  THROUGH    STEEL  MEDIUM     S
# 29  E32   HIGHWAY      ?     2     G  THROUGH     IRON  MEDIUM     F
# 30  E31        RR   1161     2     G  THROUGH    STEEL  MEDIUM     S
# 31  E34        RR   4558     2     G  THROUGH    STEEL    LONG     F
# 32  E33   HIGHWAY   1120     ?     G  THROUGH     IRON  MEDIUM     F
# 33  E36   HIGHWAY      ?     2     G  THROUGH     IRON   SHORT     F
# 34  E35   HIGHWAY   1000     2     G  THROUGH    STEEL  MEDIUM     F
